# %%
#import pandas
import pandas as pd

# %%
#import csv
df = pd.read_csv('CricketTestMatchData.csv')

# %%
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 2      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
#rename multiple columns in a list
df = df.rename(columns= {'Mat':'Matches' , 'NO':'Not_Outs', 'HS' : 'Highest_Inns_Score', 'BF': 'Balls_Faced', 'SR': 'Batting_Strike_Rate'} )

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 60   KD Walters (AUS)  1965-1981       74   125        14  5357
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
#check for null values
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df [df ['Batting_Strike_Rate'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Span, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s]
# Index: []

# %%
#replace some
df['Balls_Faced'] =  df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] =  df['Batting_Strike_Rate'].fillna(0)

# %%
# drop the duplicates
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 65, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                  Player       Span  Matches  Inns  Not_Outs  Runs  \
# 16       L Hutton (ENG)  1937-1955       79   138        15  6971
# 21        CA Davis (WI)  1968-1973       15    29         5  1301
# 48  M Labuschagne (AUS)  2018-2024       50    90         7  4114
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 16                364  56.67       2844+                39.34   19  33  5
# 21                183  54.20        665+                35.48    4   4  1
# 48                215  49.56        7809                52.68   11  20  4
#
#      4s  6s
# 16  358   7
# 21   65   1
# 48  463  12

# %%
df[df['Player'].isin(['L Hutton (ENG)', 'CA Davis (WI)','M Labuschagne (AUS)'])]
# Out:
#                  Player       Span  Matches  Inns  Not_Outs  Runs  \
# 15       L Hutton (ENG)  1937-1955       79   138        15  6971
# 20        CA Davis (WI)  1968-1973       15    29         5  1301
# 47  M Labuschagne (AUS)  2018-2024       50    90         7  4114
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50  0  \
# 15                364  56.67       2844+                39.34   19  33  5
# 20                183  54.20        665+                35.48    4   4  1
# 47                215  49.56        7809                52.68   11  20  4
#
#      4s  6s
# 15  358   7
# 20   65   1
# 47  463  12

# %%
df = df.drop_duplicates()

# %%
#split up span into start and end data
df['Span'].str.split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 60    [1965, 1981]
# 61    [2002, 2014]
# 62    [1924, 1934]
# 63    [1930, 1938]
# 64    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Rookie-Year'] = df['Span'].str.split(pat = '-').str[0]
# Out:
# <ipython-input-33-852d13e84e14>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Rookie-Year'] = df['Span'].str.split(pat = '-').str[0]

# %%
df['Final-Year'] = df['Span'].str.split(pat = '-').str[1]
# Out:
# <ipython-input-34-bb1b501f5684>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Final-Year'] = df['Span'].str.split(pat = '-').str[1]

# %%
df
# Out:
#                Player       Span  Matches  Inns  Not_Outs  Runs  \
# 0    DG Bradman (AUS)  1928-1948       52    80        10  6996
# 1      HC Brook (ENG)  2022-2023       12    20         1  1181
# 2      AC Voges (AUS)  2015-2016       20    31         7  1485
# 3     RG Pollock (SA)  1963-1970       23    41         4  2256
# 4     GA Headley (WI)  1930-1954       22    40         4  2190
# ..                ...        ...      ...   ...       ...   ...
# 60   KD Walters (AUS)  1965-1981       74   125        14  5357
# 61  GC Smith (ICC/SA)  2002-2014      117   205        13  9265
# 62  WH Ponsford (AUS)  1924-1934       29    48         4  2122
# 63    SJ McCabe (AUS)  1930-1938       39    62         5  2748
# 64   DR Jardine (ENG)  1928-1934       22    33         6  1296
#
#    Highest_Inns_Score    Ave Balls_Faced  Batting_Strike_Rate  100  50   0  \
# 0                 334  99.94       9800+                58.60   29  13   7
# ...

# %%
#remove the span column
df = df.drop(['Span'],axis=1)

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score  \
# 0    DG Bradman (AUS)       52    80        10  6996                334
# 1      HC Brook (ENG)       12    20         1  1181                186
# 2      AC Voges (AUS)       20    31         7  1485               269*
# 3     RG Pollock (SA)       23    41         4  2256                274
# 4     GA Headley (WI)       22    40         4  2190               270*
# ..                ...      ...   ...       ...   ...                ...
# 60   KD Walters (AUS)       74   125        14  5357                250
# 61  GC Smith (ICC/SA)      117   205        13  9265                277
# 62  WH Ponsford (AUS)       29    48         4  2122                266
# 63    SJ McCabe (AUS)       39    62         5  2748                232
# 64   DR Jardine (ENG)       22    33         6  1296                127
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie-Year  \
# ...

# %%
## QUESTION -> SPLIT up the country from the player.
df['Name'], df['Country'] = df['Player'].str.extract(r'^(.*)\s\((.*)\)$')

# %%
df
# Out:
#                Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score  \
# 0    DG Bradman (AUS)       52    80        10  6996                334
# 1      HC Brook (ENG)       12    20         1  1181                186
# 2      AC Voges (AUS)       20    31         7  1485               269*
# 3     RG Pollock (SA)       23    41         4  2256                274
# 4     GA Headley (WI)       22    40         4  2190               270*
# ..                ...      ...   ...       ...   ...                ...
# 60   KD Walters (AUS)       74   125        14  5357                250
# 61  GC Smith (ICC/SA)      117   205        13  9265                277
# 62  WH Ponsford (AUS)       29    48         4  2122                266
# 63    SJ McCabe (AUS)       39    62         5  2748                232
# 64   DR Jardine (ENG)       22    33         6  1296                127
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie-Year  \
# ...

# %%
print(df['Player'].head())
# Out:
# 0    DG Bradman (AUS)
# 1      HC Brook (ENG)
# 2      AC Voges (AUS)
# 3     RG Pollock (SA)
# 4     GA Headley (WI)
# Name: Player, dtype: object

# %%
df[['Name', 'Country']] = df['Player'].str.extract(r'^(.*?)\s*\(([^)]+)\)$')

# %%
print(df[['Player', 'Name', 'Country']])
# Check rows where 'Name' or 'Country' extraction failed
print(df[df['Name'].isna() | df['Country'].isna()])
df['Player'] = df['Player'].str.replace(r'\s*\([^)]+\)$', '', regex=True)
# Out:
#                Player         Name Country
# 0    DG Bradman (AUS)   DG Bradman     AUS
# 1      HC Brook (ENG)     HC Brook     ENG
# 2      AC Voges (AUS)     AC Voges     AUS
# 3     RG Pollock (SA)   RG Pollock      SA
# 4     GA Headley (WI)   GA Headley      WI
# ..                ...          ...     ...
# 60   KD Walters (AUS)   KD Walters     AUS
# 61  GC Smith (ICC/SA)     GC Smith  ICC/SA
# 62  WH Ponsford (AUS)  WH Ponsford     AUS
# 63    SJ McCabe (AUS)    SJ McCabe     AUS
# 64   DR Jardine (ENG)   DR Jardine     ENG
#
# [62 rows x 3 columns]
# Empty DataFrame
# Columns: [Player, Matches, Inns, Not_Outs, Runs, Highest_Inns_Score, Ave, Balls_Faced, Batting_Strike_Rate, 100, 50, 0, 4s, 6s, Rookie-Year, Final-Year, Name, Country]
# Index: []

# %%
df = df.drop(columns=['Name'])

# %%
df
# Out:
#          Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman       52    80        10  6996                334  99.94
# 1      HC Brook       12    20         1  1181                186  62.15
# 2      AC Voges       20    31         7  1485               269*  61.87
# 3    RG Pollock       23    41         4  2256                274  60.97
# 4    GA Headley       22    40         4  2190               270*  60.83
# ..          ...      ...   ...       ...   ...                ...    ...
# 60   KD Walters       74   125        14  5357                250  48.26
# 61     GC Smith      117   205        13  9265                277  48.25
# 62  WH Ponsford       29    48         4  2122                266  48.22
# 63    SJ McCabe       39    62         5  2748                232  48.21
# 64   DR Jardine       22    33         6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie-Year  \
# ...

# %%
df.head()
# Out:
#        Player  Matches  Inns  Not_Outs  Runs Highest_Inns_Score    Ave  \
# 0  DG Bradman       52    80        10  6996                334  99.94
# 1    HC Brook       12    20         1  1181                186  62.15
# 2    AC Voges       20    31         7  1485               269*  61.87
# 3  RG Pollock       23    41         4  2256                274  60.97
# 4  GA Headley       22    40         4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s Rookie-Year  \
# 0       9800+                58.60   29  13  7  626   6        1928
# 1        1287                91.76    4   7  1  141  23        2022
# 2        2667                55.68    5   4  2  186   5        2015
# 3       1707+                54.48    7  11  1  246  11        1963
# 4        416+                56.00   10   5  2  104   1        1930
#
#   Final-Year Country
# 0       1948     AUS
# 1       2023     ENG
# 2       2016     AUS
# 3       1970      SA
# ...

# %%
#change data types
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie-Year             object
# Final-Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat = '*').str[0]
# Out:
# 0     334
# 1     186
# 2     269
# 3     274
# 4     270
#      ...
# 60    250
# 61    277
# 62    266
# 63    232
# 64    127
# Name: Highest_Inns_Score, Length: 62, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat = '*').str[0]

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie-Year              int64
# Final-Year               int64
# Country                 object
# dtype: object

# %%
## QUESTION FIX THE FIRST ROOKIE YEAR AND THE FINAL YEAR AS INT NOT OBJECTS (STRINGS)
df = df.astype({'Rookie-Year' : 'int', 'Final-Year':'int'})

# %%
df.head()
# Out:
#        Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 0  DG Bradman       52    80        10  6996                 334  99.94
# 1    HC Brook       12    20         1  1181                 186  62.15
# 2    AC Voges       20    31         7  1485                 269  61.87
# 3  RG Pollock       23    41         4  2256                 274  60.97
# 4  GA Headley       22    40         4  2190                 270  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie-Year  \
# 0        9800                58.60   29  13  7  626   6         1928
# 1        1287                91.76    4   7  1  141  23         2022
# 2        2667                55.68    5   4  2  186   5         2015
# 3        1707                54.48    7  11  1  246  11         1963
# 4         416                56.00   10   5  2  104   1         1930
#
#    Final-Year Country
# 0        1948     AUS
# 1        2023     ENG
# 2        2016     AUS
# 3        1970      SA
# ...

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat = '+').str[0]

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie-Year            False
# Final-Year             False
# Country                False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#       Player  Matches  Inns  Not_Outs  Runs  Highest_Inns_Score    Ave  \
# 8  ED Weekes       48    81         5  4455                 207  58.61
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie-Year  \
# 8         NaN                  0.0   15  19  6  258   2         1948
#
#    Final-Year Country
# 8        1958      WI

# %%
df.head(62)
# Out:
#               Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0         DG Bradman       52    80        10   6996                 334
# 1           HC Brook       12    20         1   1181                 186
# 2           AC Voges       20    31         7   1485                 269
# 3         RG Pollock       23    41         4   2256                 274
# 4         GA Headley       22    40         4   2190                 270
# 5        H Sutcliffe       54    84         9   4555                 194
# 6          E Paynter       20    31         5   1540                 243
# 7      KF Barrington       82   131        15   6806                 256
# 8          ED Weekes       48    81         5   4455                 207
# 9         WR Hammond       85   140        16   7249                 336
# 10         GS Sobers       93   160        21   8032                 365
# 11     KC Sangakkara      134   233        17  12400                 319
# ...

# %%
df = df.drop (8,axis =0)

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# Not_Outs               False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie-Year            False
# Final-Year             False
# Country                False
# dtype: bool

# %%
df['Balls_Faced'] = df['Balls_Faced'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# Not_Outs                 int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                        int64
# 4s                       int64
# 6s                       int64
# Rookie-Year              int64
# Final-Year               int64
# Country                 object
# dtype: object

# %%
##QUESTION 1 - > CRICKETERS IN THIS COLUMN WHAT IS THE AVG CARRER LENGTH
df['career_length'] = df['Final-Year'] - df['Rookie-Year']
df
# Out:
#               Player  Matches  Inns  Not_Outs   Runs  Highest_Inns_Score  \
# 0         DG Bradman       52    80        10   6996                 334
# 1           HC Brook       12    20         1   1181                 186
# 2           AC Voges       20    31         7   1485                 269
# 3         RG Pollock       23    41         4   2256                 274
# 4         GA Headley       22    40         4   2190                 270
# 5        H Sutcliffe       54    84         9   4555                 194
# 6          E Paynter       20    31         5   1540                 243
# 7      KF Barrington       82   131        15   6806                 256
# 9         WR Hammond       85   140        16   7249                 336
# 10         GS Sobers       93   160        21   8032                 365
# 11     KC Sangakkara      134   233        17  12400                 319
# 12         SPD Smith      109   195        25   9685                 239
# ...

# %%
df['career_length'].mean()
# Out:
# 13.288135593220339

# %%
##question2: avg batting strike rate for palyer who palyed over 10 years
df[df['career_length'] >10 ]['Batting_Strike_Rate'].mean()
# Out:
# 50.23

# %%
##question 3:  find number of cricketers who played before 1960
df[df['Rookie-Year']<1960]['Player'].count()
# Out:
# 20

# %%
##question 4 max highest inss by country

# %%
df.groupby('Country')['Highest_Inns_Score'].max().to_frame('Highinncountry').reset_index().sort_values('Highinncountry', ascending = False )
# Out:
#     Country  Highinncountry
# 5    ICC/WI             400
# 0       AUS             380
# 10       SL             374
# 11       WI             365
# 1       ENG             364
# 3   ICC/PAK             329
# 2   ICC/IND             319
# 8       PAK             313
# 9        SA             278
# 4    ICC/SA             277
# 6       IND             254
# 7        NZ             251
# 12      ZIM             232

# %%
##question 5 hundreds, fifties, ducks(0) avg by country
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      20.625000  28.375000   8.562500
# ENG      13.000000  22.083333   4.416667
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      29.500000  36.500000  10.750000
# NZ       18.500000  22.000000   6.000000
# PAK      21.250000  28.000000   9.500000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       17.166667  28.666667   8.500000
# ZIM      12.000000  27.000000   5.000000
